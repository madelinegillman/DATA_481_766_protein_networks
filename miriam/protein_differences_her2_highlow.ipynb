# %%
# protein_differences_her2_highlow.ipynb

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import scipy
import matplotlib.pyplot as plt
from statannot import add_stat_annotation
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
sns.set(style="whitegrid")

# %%
# Load the dataset for the H2170 lung cancer cell line
# We call its container "df_cell", which stands for dataFrame of the cell line that holds all of the single-cell protein measurements
df_cell = pd.read_csv('/Users/22holleranm/DATA_481_766_protein_networks/shared_team_files/lung_cancer.csv', index_col=0)

# Display the first few rows
df_cell.head()
# Out:
#               01_cMyc_nuc_mean  01_BRD4_nuc_mean  01_CDK2_nuc_mean  \
# index_column
# cell_24              -0.274626         -0.632049          0.130158
# cell_31               0.545061          0.302935          0.875525
# cell_36               0.478836         -0.622209         -0.316807
# cell_43              -0.747665         -1.171727         -0.779043
# cell_51              -0.969321         -0.830915         -0.439126
#
#               02_HER2_nuc_mean  02_CyclinD1_nuc_mean  02_EGFR_nuc_mean  \
# index_column
# cell_24               0.996370             -0.217049         -0.177764
# cell_31               0.416186             -0.523494         -0.444546
# cell_36               0.273643             -0.855136         -0.445459
# cell_43              -0.258488             -1.004050         -0.582779
# cell_51               0.909262             -0.538657          1.243933
#
#               03_FGFR2_nuc_mean  03_CDC6_nuc_mean  03_EZH2_nuc_mean  \
# index_column
# cell_24                0.109605          1.356144          0.482767
# cell_31               -0.218084          0.560125          0.388460
# cell_36               -0.495221          0.306739         -0.401794
# cell_43               -0.864614         -0.471185         -0.527605
# cell_51               -0.292941         -0.317952          0.356104
#
#               04_cMycS62_nuc_mean  04_FOXO1_nuc_mean  04_HER2_nuc_mean  \
# index_column
# cell_24                 -0.536020          -0.987532         -0.897249
# cell_31                  0.624579          -0.696834         -0.698082
# cell_36                  0.390856          -0.824935         -0.611346
# cell_43                 -0.821571          -0.864645         -0.990543
# cell_51                 -1.060728          -0.793165          0.505676
#
#               05_cMycT58_nuc_mean  05_CyclinA_nuc_mean  05_CyclinB1_nuc_mean  \
# index_column
# cell_24                  0.243860            -0.927233             -0.002703
# cell_31                  0.404130             0.377436              0.506497
# cell_36                 -0.104029            -0.369246             -0.081758
# cell_43                 -0.607014            -0.717098             -0.687771
# cell_51                 -0.859886            -0.976564             -0.010725
#
#               06_FOXO3A_nuc_mean  06_AKT_nuc_mean  06_ZEB1_nuc_mean  \
# index_column
# cell_24                 0.406510        -0.457381          0.887332
# cell_31                 0.032809        -0.538555          0.346244
# cell_36                 0.202629        -0.745466         -0.057875
# cell_43                 0.153157        -0.843331         -0.112361
# cell_51                -0.142979         0.121853          1.201399
#
#               07_pRb_S807811_nuc_mean  07_Rb_nuc_mean  07_p21_nuc_mean  \
# index_column
# cell_24                      0.114794       -0.430899         1.254235
# cell_31                      1.209497        0.987865         0.753873
# cell_36                      0.507749        0.167409         0.202370
# cell_43                      0.669902        0.363792        -0.009721
# cell_51                     -1.370445       -1.067327         0.643206
#
#               08_CDT1_nuc_mean  08_MDM2_nuc_mean  09_SKP2_nuc_mean  \
# index_column
# cell_24               1.871959          0.461608          0.422949
# cell_31              -0.235938         -0.070285          1.566281
# cell_36              -0.516313         -0.422799          1.228007
# cell_43              -0.684535         -0.385856          0.154523
# cell_51              -0.438881          1.183240         -0.800889
#
#               09_mTOR_nuc_mean  10_TGFbeta_nuc_mean  10_E2F1_nuc_mean  \
# index_column
# cell_24               1.406970            -0.434054         -0.922134
# cell_31               0.917627            -0.004364         -0.017985
# cell_36               0.500917             0.007855         -0.462886
# cell_43               0.359326            -0.237356         -0.532523
# cell_51               0.762989            -0.426352         -0.661457
#
#               11_cFOS_nuc_mean  11_CDH1_nuc_mean  12_EZH2_nuc_mean  \
# index_column
# cell_24               0.300361          0.737689          0.626121
# cell_31               0.250767          0.057809          1.478013
# cell_36              -0.072239         -0.370941          0.222873
# cell_43              -0.709584         -0.514982         -0.161593
# cell_51               0.552717          0.289812         -0.649461
#
#               12_cPARP_nuc_mean  01_cMyc_ring_mean  01_BRD4_ring_mean  \
# index_column
# cell_24                0.519019           0.448048           0.108275
# cell_31                0.019616           0.485509           0.248573
# cell_36               -0.226078           0.010196          -0.094905
# cell_43               -0.454719          -0.630292          -0.822400
# cell_51                0.332243          -0.781621          -0.739925
#
#               01_CDK2_ring_mean  02_HER2_ring_mean  02_CyclinD1_ring_mean  \
# index_column
# cell_24                0.868095           1.319311               0.076730
# cell_31                0.915782           0.890622              -0.143222
# cell_36               -0.103745           0.236957              -0.593180
# cell_43               -0.832541          -0.554567              -0.941967
# cell_51               -0.295508          -0.289053              -0.793799
#
#               02_EGFR_ring_mean  03_FGFR2_ring_mean  03_CDC6_ring_mean  \
# index_column
# cell_24               -0.006708            0.263158           1.385566
# cell_31               -0.101312            0.144229           1.156873
# cell_36               -0.307542           -0.419718           0.570195
# cell_43               -0.596149           -1.019525          -0.729150
# cell_51                0.237827           -0.965990          -0.560119
#
#               03_EZH2_ring_mean  04_cMycS62_ring_mean  04_FOXO1_ring_mean  \
# index_column
# cell_24                0.719334             -0.402828           -1.048042
# cell_31                0.543466             -0.333130           -0.913026
# cell_36               -0.181529             -0.053759           -0.641108
# cell_43               -0.704892             -0.751484           -0.915185
# cell_51               -0.547636             -0.961859           -0.932757
#
#               04_HER2_ring_mean  05_cMycT58_ring_mean  05_CyclinA_ring_mean  \
# index_column
# cell_24               -0.925909              0.334180             -0.284215
# cell_31               -0.713302              0.266901              0.122589
# cell_36               -0.577423             -0.191195             -0.458681
# cell_43               -0.971186             -0.599293             -1.009942
# cell_51               -0.198326             -0.748682             -0.974881
#
#               05_CyclinB1_ring_mean  06_FOXO3A_ring_mean  06_AKT_ring_mean  \
# index_column
# cell_24                    1.325648             0.513783         -0.151589
# cell_31                    1.330254             0.379366         -0.188642
# cell_36                    0.032330            -0.024514         -0.642016
# cell_43                   -0.901189            -0.389840         -0.950625
# cell_51                   -0.024452            -0.455724          0.159394
#
#               06_ZEB1_ring_mean  07_pRb_S807811_ring_mean  07_Rb_ring_mean  \
# index_column
# cell_24                0.874221                  0.929768         0.446487
# cell_31                0.686795                  0.582482         0.476434
# cell_36               -0.014706                  0.181128        -0.018302
# cell_43               -0.224062                 -0.203456        -0.321853
# cell_51                0.509263                 -0.987530        -0.904973
#
#               07_p21_ring_mean  08_CDT1_ring_mean  08_MDM2_ring_mean  \
# index_column
# cell_24               1.270743           1.188206           0.365427
# cell_31               0.979811           0.417119           0.159226
# cell_36               0.199695          -0.165359          -0.282927
# cell_43              -0.140230          -0.670966          -0.392751
# cell_51               0.023986          -0.653298           0.458529
#
#               09_SKP2_ring_mean  09_mTOR_ring_mean  10_TGFbeta_ring_mean  \
# index_column
# cell_24                1.164822           1.464958             -0.378041
# cell_31                1.409255           1.360996             -0.186646
# cell_36                0.601053           0.460337              0.176087
# cell_43               -0.139191          -0.018206             -0.421827
# cell_51               -0.634196           0.037728             -0.661620
#
#               10_E2F1_ring_mean  11_cFOS_ring_mean  11_CDH1_ring_mean  \
# index_column
# cell_24               -0.906202           0.209302           0.589119
# cell_31               -0.669842           0.128295           0.240999
# cell_36               -0.256244          -0.202937          -0.290657
# cell_43               -0.582895          -0.898908          -0.599372
# cell_51               -0.765564          -0.566221          -0.498345
#
#               12_EZH2_ring_mean  12_cPARP_ring_mean
# index_column
# cell_24                0.940516            0.368686
# cell_31                0.956225            0.188836
# cell_36                0.158839           -0.211352
# cell_43               -0.398471           -0.556434
# cell_51               -0.757989           -0.509151

# %%
# Combining HER2 measurements from nuclear and cytoplasmic intensities

# Set up containers for combined HER2 intensities
combined_HER2_intensity_02 = []
combined_HER2_intensity_04 = []

# Load your data
data = df_cell  # Use the main dataset

# Define the HER2 conditions for each fluorophore/antibody, for iteration 2 and 4
conditions_02 = ['02_HER2_nuc_mean', '02_HER2_ring_mean']
conditions_04 = ['04_HER2_nuc_mean', '04_HER2_ring_mean']

# Compute combined HER2 intensities for iteration 02
for i in data.index:
    # Average nuclear and cytoplasmic HER2 measurements
    tmp = (data.loc[i, '02_HER2_nuc_mean'] + data.loc[i, '02_HER2_ring_mean']) / 2
    combined_HER2_intensity_02.append(tmp)

# Compute combined HER2 intensities for iteration 04
for i in data.index:
    tmp = (data.loc[i, '04_HER2_nuc_mean'] + data.loc[i, '04_HER2_ring_mean']) / 2
    combined_HER2_intensity_04.append(tmp)

# Add the combined HER2 intensities as new columns in the dataset
data['02_HER2_combined'] = combined_HER2_intensity_02
data['04_HER2_combined'] = combined_HER2_intensity_04

all_nuc_or_cyt = ['01_cMyc_nuc_mean', '01_BRD4_nuc_mean', '01_CDK2_nuc_mean', '02_CyclinD1_nuc_mean', 
 '03_CDC6_nuc_mean', '03_EZH2_nuc_mean', '04_cMycS62_nuc_mean', '04_FOXO1_nuc_mean', 
 '05_cMycT58_nuc_mean', '05_CyclinA_nuc_mean', '05_CyclinB1_nuc_mean', '06_FOXO3A_nuc_mean', 
 '06_ZEB1_nuc_mean', '07_pRb_S807811_nuc_mean', '07_Rb_nuc_mean', '07_p21_nuc_mean', 
 '08_CDT1_nuc_mean', '08_MDM2_nuc_mean', '09_SKP2_nuc_mean', '10_TGFbeta_nuc_mean', 
 '10_E2F1_nuc_mean', '11_cFOS_nuc_mean', '12_EZH2_nuc_mean', '12_cPARP_nuc_mean']

selection = all_nuc_or_cyt

# %%
# Iteration 02

# Dataset and HER2 condition column
data = df_cell
cond = '02_HER2_combined'  # Column representing HER2 combined expression

# Identify the top and bottom 10% of HER2 expression
top_10_percent = data[cond].quantile(0.9)  # Value at the 90th percentile
bottom_10_percent = data[cond].quantile(0.1)  # Value at the 10th percentile

# Add a new column to label the HER2 groups
data['HER2_Group'] = 'Middle'  # Default to 'Middle' group
data.loc[data[cond] >= top_10_percent, 'HER2_Group'] = 'High HER2'  # Top 10%
data.loc[data[cond] <= bottom_10_percent, 'HER2_Group'] = 'Low HER2'  # Bottom 10%

# Verify the new column and data
print("Updated dataset with HER2 groups:")
print(data[['HER2_Group', cond]].head())  # Display the HER2 group and condition

data_high_02 = data[data.HER2_Group=='High HER2'].drop('HER2_Group',axis=1)[selection]
data_low_02 = data[data.HER2_Group=='Low HER2'].drop('HER2_Group',axis=1)[selection]
# Out:
# Updated dataset with HER2 groups:
#              HER2_Group  02_HER2_combined
# index_column
# cell_24       High HER2          1.157840
# cell_31       High HER2          0.653404
# cell_36          Middle          0.255300
# cell_43          Middle         -0.406528
# cell_51          Middle          0.310104

# %%
# Iteration 04

# Dataset and HER2 condition column
data = df_cell
cond = '04_HER2_combined'  # Column representing HER2 combined expression

# Identify the top and bottom 10% of HER2 expression
top_10_percent = data[cond].quantile(0.9)  # Value at the 90th percentile
bottom_10_percent = data[cond].quantile(0.1)  # Value at the 10th percentile

# Add a new column to label the HER2 groups
data['HER2_Group'] = 'Middle'  # Default to 'Middle' group
data.loc[data[cond] >= top_10_percent, 'HER2_Group'] = 'High HER2'  # Top 10%
data.loc[data[cond] <= bottom_10_percent, 'HER2_Group'] = 'Low HER2'  # Bottom 10%

# Verify the new column and data
print("Updated dataset with HER2 groups:")
print(data[['HER2_Group', cond]].head())  # Display the HER2 group and condition

data_high_04 = data[data.HER2_Group=='High HER2'].drop('HER2_Group',axis=1)[selection]
data_low_04 = data[data.HER2_Group=='Low HER2'].drop('HER2_Group',axis=1)[selection]
# Out:
# Updated dataset with HER2 groups:
#              HER2_Group  04_HER2_combined
# index_column
# cell_24        Low HER2         -0.911579
# cell_31          Middle         -0.705692
# cell_36          Middle         -0.594384
# cell_43        Low HER2         -0.980865
# cell_51          Middle          0.153675

# %%
def compare_protein_expression(high_group, low_group, iteration_label):
    print(f"\nProtein Expression Comparison: {iteration_label}")
    results = []
    m = len(selection)

    for protein in selection:
        stat, p = stats.mannwhitneyu(high_group[protein], low_group[protein], alternative='two-sided')
        p_bonf = min(p * m, 1.0)
        significance = ''
        if p_bonf < 0.001:
            significance = '***'
        elif p_bonf < 0.01:
            significance = '**'
        elif p_bonf < 0.05:
            significance = '*'
        
        print(f"{protein}: raw p = {p:.4e}, Bonferroni p = {p_bonf:.4e} {significance}")
        results.append((protein, p, p_bonf))

    return pd.DataFrame(results, columns=['Protein', 'p_value_raw', 'p_value_bonferroni'])

results_02 = compare_protein_expression(data_high_02, data_low_02, 'Iteration 02')
results_04 = compare_protein_expression(data_high_04, data_low_04, 'Iteration 04')
# Out:
# Protein Expression Comparison: Iteration 02
# 01_cMyc_nuc_mean: raw p = 2.3358e-268, Bonferroni p = 5.6060e-267 ***
# 01_BRD4_nuc_mean: raw p = 1.8606e-152, Bonferroni p = 4.4654e-151 ***
# 01_CDK2_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 02_CyclinD1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 03_CDC6_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 03_EZH2_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 04_cMycS62_nuc_mean: raw p = 3.8226e-301, Bonferroni p = 9.1742e-300 ***
# 04_FOXO1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 05_cMycT58_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 05_CyclinA_nuc_mean: raw p = 1.5272e-195, Bonferroni p = 3.6653e-194 ***
# 05_CyclinB1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 06_FOXO3A_nuc_mean: raw p = 5.2438e-57, Bonferroni p = 1.2585e-55 ***
# 06_ZEB1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 07_pRb_S807811_nuc_mean: raw p = 1.1519e-81, Bonferroni p = 2.7647e-80 ***
# 07_Rb_nuc_mean: raw p = 5.7022e-111, Bonferroni p = 1.3685e-109 ***
# 07_p21_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 08_CDT1_nuc_mean: raw p = 8.2964e-153, Bonferroni p = 1.9911e-151 ***
# 08_MDM2_nuc_mean: raw p = 1.2175e-107, Bonferroni p = 2.9220e-106 ***
# 09_SKP2_nuc_mean: raw p = 2.3961e-234, Bonferroni p = 5.7506e-233 ***
# 10_TGFbeta_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 10_E2F1_nuc_mean: raw p = 5.9566e-287, Bonferroni p = 1.4296e-285 ***
# 11_cFOS_nuc_mean: raw p = 2.6962e-291, Bonferroni p = 6.4708e-290 ***
# 12_EZH2_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 12_cPARP_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
#
# Protein Expression Comparison: Iteration 04
# 01_cMyc_nuc_mean: raw p = 1.0846e-223, Bonferroni p = 2.6029e-222 ***
# 01_BRD4_nuc_mean: raw p = 2.2027e-120, Bonferroni p = 5.2866e-119 ***
# 01_CDK2_nuc_mean: raw p = 1.2344e-285, Bonferroni p = 2.9625e-284 ***
# 02_CyclinD1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 03_CDC6_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 03_EZH2_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 04_cMycS62_nuc_mean: raw p = 1.1480e-309, Bonferroni p = 2.7553e-308 ***
# 04_FOXO1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 05_cMycT58_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 05_CyclinA_nuc_mean: raw p = 1.0473e-144, Bonferroni p = 2.5135e-143 ***
# 05_CyclinB1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 06_FOXO3A_nuc_mean: raw p = 1.0142e-115, Bonferroni p = 2.4340e-114 ***
# 06_ZEB1_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 07_pRb_S807811_nuc_mean: raw p = 3.3004e-93, Bonferroni p = 7.9210e-92 ***
# 07_Rb_nuc_mean: raw p = 6.4053e-86, Bonferroni p = 1.5373e-84 ***
# 07_p21_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 08_CDT1_nuc_mean: raw p = 2.3033e-149, Bonferroni p = 5.5280e-148 ***
# 08_MDM2_nuc_mean: raw p = 2.1087e-289, Bonferroni p = 5.0608e-288 ***
# 09_SKP2_nuc_mean: raw p = 1.1835e-100, Bonferroni p = 2.8403e-99 ***
# 10_TGFbeta_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 10_E2F1_nuc_mean: raw p = 2.0739e-233, Bonferroni p = 4.9774e-232 ***
# 11_cFOS_nuc_mean: raw p = 0.0000e+00, Bonferroni p = 0.0000e+00 ***
# 12_EZH2_nuc_mean: raw p = 1.6595e-247, Bonferroni p = 3.9827e-246 ***
# 12_cPARP_nuc_mean: raw p = 3.1078e-258, Bonferroni p = 7.4587e-257 ***
